# %% [markdown]
#    <center>
# </center>
#    <center>
#     <h3 style = "color:green">Activity10-Designing the Python Class for the Perceptron Model
# (Implementing a Perceptron Learning Algorithm in Python)</h3>
# </center>
#     <img src="images/machine_learning.jpg" width=200; height=200>
#     <center>
#     <h3 style="color:green">Pre-Project/Final Exam</h3>
#     </center>
#
# ### by Joshua Brewington
#
# <h2><u>Objectives</u></h2>
#
# - Start designing a Python Perceptron Class
# - Create a professional looking Jupyter Notebook.
# - Use several NumPy functions to implement the class.
# - Create dummy feature matrix.
# - Instantiate and testing the Python Peceptron Class
#
# ***Instructions***
# - Let’s begin creating the class for our perceptron implementation in python . Type the code below into your favorite python editor (doing it in Jupyter Notebook is probably better).
# - Complete each item labeled TASK in the order indicated.
#
# <h4 style="color:orange">Enter the code in the cell below</h4>

# %%
import numpy as np

class Perceptron(object):
    """Perceptron classifier.
    Parameters
    ------------
    eta : float
        Learning rate (between 0.0 and 1.0)
        n_iter : int
            Passes over the training dataset.
            
    Attributes
    ------------
    w_ : 1d-array
        Weights after fitting.
    errors_ : list
        Number of misclassifications in every epoch.
        
    """
    def __init__(self, eta =0.01, n_iter=10):
        self.eta = eta
        self.n_iter = n_iter
        
    def fit(self,X_shape):
        self.w_ = np.zeros(1 + X.shape[1]) + 0.5
        #TASK 3 - override above and set all weights arbitrarily to 0.5
        
        #TASK 4 - Add print statements to print the net_input() and predict() methods
        #just doing this to call the methods of the class for testing
        
    def net_input(self,X):
        """Calculate net input"""
        return np.dot(X,self.w_[1:])+self.w_[0]
        
    def predict(self,X):
        """Return class label after unit step"""
        net_input = self.net_input(X)
        print(f'Net input: {net_input}')
        return np.where(net_input>= 0.0, 1, -1)
        
#def main():
    #TASK 0 - Print out the class and methods docstrings as help
    #help(Perceptron)
    #TASK 1 - create (and populate!) a 2D dummy features matrix, name it features
    
    #TASK 2 - covert to numpy array and assign to X
    
    #TASK 5 - instantiate the class. name the object ppn
    
    #TASK 6 - call the dummy fit() method using your array
    
#if __name__== main():
    #main()

# %% [markdown]
# The above code is self contained and can be executed as a stand-alone program. However, since we typed the code directly into this Jupyter Notebook, you can get rid of def main() , etc. and just keep the skeletal Perceptron class. You will also need to merge this code/notebook with that from previous exercises and labs, shortly.

# %% [markdown]
# #### TASK 0 - Print out the class and methods docstrings as help

# %%
help(Perceptron)
# the help function is describing what the Perceptron class does
# Out:
# Help on class Perceptron in module __main__:
#
# class Perceptron(builtins.object)
#  |  Perceptron(eta=0.01, n_iter=10)
#  |
#  |  Perceptron classifier.
#  |  Parameters
#  |  ------------
#  |  eta : float
#  |      Learning rate (between 0.0 and 1.0)
#  |      n_iter : int
#  |          Passes over the training dataset.
#  |
#  |  Attributes
#  |  ------------
#  |  w_ : 1d-array
#  |      Weights after fitting.
#  |  errors_ : list
#  |      Number of misclassifications in every epoch.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, eta=0.01, n_iter=10)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  fit(self, X_shape)
#  |
#  |  net_input(self, X)
#  |      Calculate net input
#  |
#  |  predict(self, X)
#  |      Return class label after unit step
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
# ...

# %% [markdown]
# The cell above displays the help instructions for the perceptron class.

# %% [markdown]
# #### TASK 1 - create (and populate!) a 2D dummy features matrix.
# Keep it simple and make it 2 x 2 python list. Give it the name features

# %%
features = [[3,5],[-2,-6]]
# create a 2D list

# %% [markdown]
# Here we created a 2D list with postive and negative integers.

# %% [markdown]
# #### TASK 2 - convert to numpy array

# %%
X = np.array(features)
# run the variable features through the numpy.array() function

# %% [markdown]
# This cell is setting the features in a numpy array set to a variable 'X'.

# %% [markdown]
# <h4 style="color:red">Go to TASK 3 and TASK 4 (See Perceptron Class)</h4>
#
# **TASK 5 - Instantiate the class**
#
# Instantiate the class with the default values in the constructor (initializer)

# %%
ppn=Perceptron()
ppn.fit(X.shape)
# the class was instantiated and the object was named ppn

# %% [markdown]
# The class was fitted with the 'X' input data.

# %% [markdown]
# #### TASK 6 - Call the dummy fit() method using your array

# %%
ppn.fit(X)
# the ppn.fit() method is training the perceptron model

# %% [markdown]
# This cell is displating the fit() method to train the model.

# %% [markdown]
# Keep playing with TASK 6 by changing the values in your dummy array to make the predict method yield both of the possible binary values 1 and
# -1. When it does, leave those values in your feature matrix.

# %%
predictions = ppn.predict(X)
print(f'Predictions: {predictions}')
# Out:
# Net input: [ 4.5 -3.5]
# Predictions: [ 1 -1]

# %% [markdown]
# <h3 style="color:orange">Question(s)</h3>
# In your own words, explain what this piece of does:
#
# #### Enter your answer in markdown in the cell below:

# %% [markdown]
# This line of code creates the weights for the data. It sets 'self.w_' to the numpy array of zeroes, which allows for the perceptron model to be trained with input data.
